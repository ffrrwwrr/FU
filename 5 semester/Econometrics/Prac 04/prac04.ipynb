# %%
import numpy as np

# %%
y = np.array([3411.5,3792.14,4094.99,5270.69,8554.06,10761.26,10087.3,9600.86,8304.96,9159.48,7555.92, # bitcoin
              7165.72,9334.98,8525.07,6424.35,8624.28,9446.57,9136.2,11351.62,11655,10779.63,
              13804.81,19713.94,28990.08,33137.74,45231.75,58800,57798.77,37279.31,35060]) 

x = np.array([[47.11,52.98,53.7,51.03,44.03,47.89,50.6,47.41,51.525, # intel
              56.58,58.07,59.84,63.9,55.52,54.12,59.95,62.83,59.82,47.72,
              50.93,51.77,44.3,48.46,49.82,55.49,60.69,64.03,57.53,57.11,56.13], 
             [143.7,154.32,179.56,181.07,135.44,164.22,168.69,167.54,174.06,201.04, # nvidia
              216.74,235.29,236.43,270.08,263.58,292.05,353.65,379.31,424.58,535,540.81,502.06,536.4,
              522.07,518.87,548.81,534.11,600.37,649.81,800.64],
             [37.63,39.095,40.96,43.83,38.76,39.36,43.025,42.49,46.43, # tsmc
              51.47,53.11,58.11,53.95,53.81,47.79,53.12,50.33,56.76,78.9,
              79.26,81.05,83.87,97.02,109.09,121.46,126.17,118.27,116.67,117.32,120.12]])

X = np.transpose(x) # transpose
X = np.c_[X, np.ones(X.shape[0])] # add ones
linreg = np.linalg.lstsq(X, y, rcond=None)[0] # решение линейного матричного уравнения методом наименьших квадратов
print(f"Vector Y:\n {y}\n\nMatrix X:\n {X}\n\nОрдинатное пересечение: \n{linreg[-1:]}\n\nКоэф.-ы перед X: \n{linreg[:-1]}")
# Out:
# Vector Y:
#  [ 3411.5   3792.14  4094.99  5270.69  8554.06 10761.26 10087.3   9600.86
#   8304.96  9159.48  7555.92  7165.72  9334.98  8525.07  6424.35  8624.28
#   9446.57  9136.2  11351.62 11655.   10779.63 13804.81 19713.94 28990.08
#  33137.74 45231.75 58800.   57798.77 37279.31 35060.  ]
#
# Matrix X:
#  [[ 47.11  143.7    37.63    1.   ]
#  [ 52.98  154.32   39.095   1.   ]
#  [ 53.7   179.56   40.96    1.   ]
#  [ 51.03  181.07   43.83    1.   ]
#  [ 44.03  135.44   38.76    1.   ]
#  [ 47.89  164.22   39.36    1.   ]
#  [ 50.6   168.69   43.025   1.   ]
#  [ 47.41  167.54   42.49    1.   ]
#  [ 51.525 174.06   46.43    1.   ]
#  [ 56.58  201.04   51.47    1.   ]
#  [ 58.07  216.74   53.11    1.   ]
#  [ 59.84  235.29   58.11    1.   ]
#  [ 63.9   236.43   53.95    1.   ]
#  [ 55.52  270.08   53.81    1.   ]
#  [ 54.12  263.58   47.79    1.   ]
#  [ 59.95  292.05   53.12    1.   ]
#  [ 62.83  353.65   50.33    1.   ]
#  [ 59.82  379.31   56.76    1.   ]
# ...
